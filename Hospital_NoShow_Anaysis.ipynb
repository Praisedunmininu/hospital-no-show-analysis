# %% [markdown]
# 🌹 Hospital Appointment No-Show Analysis
# 📖 Project Overview
#
# This project explores factors that influence whether patients attend or miss their hospital appointments. The main questions investigated are:
#
# Does receiving an SMS reminder reduce no-show chances?
#
# Which age groups miss appointments the most?
#
# Are there patterns in attendance across different ages?
#
# The analysis is done using Python, Pandas, Matplotlib, and data visualization.
#
# 📂 Dataset
#
# The dataset contains patient appointment information, including:
#
# Age
#
# SMS_received (0 = No SMS, 1 = SMS sent)
#
# No-show (Yes/No)
#
# Appointment day vs scheduled day
#
# Other demographic and medical features
#
# 🛠 Methods Used
#
# Data cleaning (handling invalid ages like −1)
#
# Feature engineering (WaitingTime)
#
# Groupby analysis for age and SMS
#
# No-show rate calculation
#
# Line chart visualizatioin
#
# 📊 Key Findings
# 1. Age strongly affects no-show rates
#
# Young patients (0–20 years) have the highest no-show rates.
#
# Adults (20–60 years) show more stable and lower no-show rates.
#
# Older adults (60–80 years) attend appointments more reliably.
#
# Very elderly data (90+) is unstable due to very small sample sizes.
#
# 2. SMS reminders were not as effective as expected
#
# Many patients who received SMS still missed their appointments.
#
# The SMS line stays above the no-SMS line for several ages.
#
# SMS alone is not enough to guarantee attendance.
#
# 3. Age 115 had a 75% no-show rate
#
# But this is based on a very small number of patients.
#
# It is considered an anomaly.
#
# 📈 Line Chart Insight
#
# The line chart shows no-show rate by age for:
#
# People who received SMS
#
# People who did not receive SMS
#
# The two lines help visualize how attendance changes with age and SMS reminders.
#
# 🧾 Conclusion
#
# Appointment attendance is influenced more by age than by SMS reminders. SMS reminders alone do not significantly reduce no-show rates. Young patients are the biggest contributors to missed appointments, while older adults attend more reliably. Future strategies should target:
#
# Young patients
#
# Multiple reminder methods (calls, same-day SMS, app notifications)
#
#
# 📦 Tools Used
#
# Python
#
# Pandas
#
# Matplotlib
